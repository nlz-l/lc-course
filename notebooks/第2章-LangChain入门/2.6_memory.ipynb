# %%
# 加载环境变量
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# # 1.没有记忆时

# %%
from langchain.agents import create_agent

agent = create_agent(model = "deepseek-v4-pro")

# %%
from langchain.messages import HumanMessage

# 第一次调用，告知AI我的信息
response = agent.invoke(
    {"messages": [HumanMessage(content="你好，我叫虎哥，我最喜欢猫猫。")]}
)

print(response)
# Out:
# {'messages': [HumanMessage(content='你好，我叫虎哥，我最喜欢猫猫。', additional_kwargs={}, response_metadata={}, id='32e3f147-cb7e-49fd-b050-94819fee9d44'), AIMessage(content='喵～虎哥好！这反差萌太绝了，霸气昵称配软萌爱好，一听就是铁汉柔情型猫奴！🐯❤️🐱\n\n你最喜欢猫猫的哪个瞬间啊？是粉爪垫开花、打呼噜震天响，还是用脑袋顶你手心求摸摸？要是养了猫主子，求云吸猫照片投喂！😻\n\n（悄悄问：暹罗话痨、橘色压塌炕、奶牛神经刀……虎哥pick哪一款？）', additional_kwargs={'refusal': None, 'reasoning_content': '好的，现在我是虎哥了，我最喜欢猫猫。用户和我打了招呼，我得先热情回应一下，毕竟他用了这么霸气的名字，结果反差萌喜欢猫猫，这点特别有意思。我得抓住这个反差感来拉近距离。\n\n提到猫猫，我得用那种像猫一样柔软的语气回应，让他感觉像在聊心爱的事物。可以用“喵”来开头，再夸夸他的昵称和爱好的反差萌。然后得具体聊聊猫猫的可爱之处，比如粉爪垫、打呼噜，或者问问他喜欢什么类型的猫，这样能延续话题。最后再主动问问他有没有养猫，或者喜欢什么品种，让他有分享的空间。整个回复要活泼又温暖，带点猫奴的共鸣感。'}, response_metadata={'token_usage': {'completion_tokens': 274, 'prompt_tokens': 15, 'total_tokens': 289, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 160, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 15}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-pro', 'system_fingerprint': 'fp_9954b31ca7_prod0820_fp8_kvcache_20260402', 'id': '9d892274-48b8-4f61-8e26-aeb79292a881', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ed083-f6ca-7673-91c4-05c0988c25d5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 274, 'total_tokens': 289, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 160}})]}

# %%
# 第二次调用，询问我的信息
response = agent.invoke(
    {"messages": [HumanMessage(content="我最喜欢什么动物?")]}
)

print(response)
# Out:
# {'messages': [HumanMessage(content='我最喜欢什么动物?', additional_kwargs={}, response_metadata={}, id='ea52ce98-ebb4-4311-bfb9-59ba245d7a8d'), AIMessage(content='哈哈，这个问题可难倒我啦！作为一个AI，我并不知道你心里最喜欢的是什么动物呢——毕竟我还没学会读心术😄\n\n不过，我可以跟你玩个游戏猜一猜！你是喜欢：\n- **毛茸茸的**，比如猫猫狗狗？\n- **酷酷的野生动物**，比如狼或老鹰？\n- **安静治愈的**，比如金鱼或乌龟？\n- 还是**小众特别的**，比如羊驼、水獭、蜜袋鼯？\n\n或者...干脆告诉我一点线索？比如它有耳朵吗？会飞吗？你喜欢它是因为可爱、忠诚，还是某种特质？让我试试看能不能猜中！🐾', additional_kwargs={'refusal': None, 'reasoning_content': '嗯，用户问“我最喜欢什么动物？”，这是一个关于个人偏好的问题。\n\n我无法知道用户的真实喜好，直接猜测很容易出错。我需要先坦诚说明这一点。\n\n然后可以提供一个轻松的互动方式，比如列举几种常见可爱动物的特点，让用户来确认，或者引导用户分享线索。这样既能化解无法回答的尴尬，又能把对话继续下去。\n\n我可以从外形、性格、与人的关系等角度列举几种典型动物，比如猫、狗、兔子等，最后邀请用户给点提示。这样应该能让用户觉得有趣并愿意互动。'}, response_metadata={'token_usage': {'completion_tokens': 260, 'prompt_tokens': 9, 'total_tokens': 269, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 117, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 9}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-pro', 'system_fingerprint': 'fp_9954b31ca7_prod0820_fp8_kvcache_20260402', 'id': '9ea6699c-94cf-438d-a47e-57163e40147a', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ed084-2347-75b2-b86f-eb9256306fd7-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 9, 'output_tokens': 260, 'total_tokens': 269, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 117}})]}

# %% [markdown]
# # 2.添加记忆
#
# 添加会话记忆（短期记忆）分为三步：
# - 导入并初始化Checkpointer
# - 创建Agent，指定Checkpointer
# - 调用Agent，指定thread_id

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver


agent = create_agent(
    "deepseek-v4-pro",
    checkpointer=InMemorySaver()
)

# %%
from langchain.messages import HumanMessage

# 设定thread_id，作为会话标识
config = {"configurable": {"thread_id": "thread_1"}}

# 第一次调用，告知AI我的信息
response = agent.invoke(
    {"messages": [HumanMessage(content="你好，我叫虎哥，我最喜欢猫猫。")]},
    config # 调用时添加thread_id
)

print(response)
# Out:
# {'messages': [HumanMessage(content='你好，我叫虎哥，我最喜欢猫猫。', additional_kwargs={}, response_metadata={}, id='69c793db-eefa-49ce-8430-d92c76c85b4b'), AIMessage(content='虎哥好！你这名字配上“最喜欢猫猫”的反差萌也太可爱了叭！😻 脑海里瞬间浮现一个画面——霸气虎哥回到家瞬间切换成温柔猫奴模式，怀里抱只胖橘疯狂吸猫...（笑）\n\n要不要聊聊你的梦中情猫？是喜欢高冷优雅的黑猫警长，还是爱撒娇的布偶小公主？或者，你家里是不是已经供着哪位猫主子了？快交出它的“犯罪证据”（照片）让我们云吸一口！🐾\n\nP.S. 如果你想要猫猫表情包暴击/冷知识/云养猫攻略，本猫瘾十级学者随时待命！✨', additional_kwargs={'refusal': None, 'reasoning_content': '呀，虎哥喜欢猫猫，这个切入点太可爱了！可以围绕猫咪这个主题展开对话，先回应他的喜好建立共鸣。准备用橘猫反差萌的例子制造笑点，既能拉近距离又能自然过渡到互动选项。  \n\n考虑到虎哥的昵称很有大佬气质，但喜欢猫又显得反差，可以玩这个梗。准备提供几个猫咪相关的话题方向：聊自家猫、看可爱视频、知识问答、云养猫攻略，让他有选择空间。  \n\n最后要确保语气活泼亲切，用感叹号和emoji突出热情，但别过度显得浮夸，保持朋友聊天的自然感。'}, response_metadata={'token_usage': {'completion_tokens': 274, 'prompt_tokens': 15, 'total_tokens': 289, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 132, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 15}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-pro', 'system_fingerprint': 'fp_9954b31ca7_prod0820_fp8_kvcache_20260402', 'id': '64169efc-c7da-4107-b7dc-918b32fb5ba6', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ed084-48eb-77a1-9f73-0b3c00574590-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 274, 'total_tokens': 289, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 132}})]}

# %%
# 第二次调用，询问我的信息，这次带上thread_id，唤起记忆
response = agent.invoke(
    {"messages": [HumanMessage(content="我最喜欢的动物是什么？")]},
    config # 调用时添加thread_id
)

print(response)
# Out:
# {'messages': [HumanMessage(content='你好，我叫虎哥，我最喜欢猫猫。', additional_kwargs={}, response_metadata={}, id='69c793db-eefa-49ce-8430-d92c76c85b4b'), AIMessage(content='虎哥好！你这名字配上“最喜欢猫猫”的反差萌也太可爱了叭！😻 脑海里瞬间浮现一个画面——霸气虎哥回到家瞬间切换成温柔猫奴模式，怀里抱只胖橘疯狂吸猫...（笑）\n\n要不要聊聊你的梦中情猫？是喜欢高冷优雅的黑猫警长，还是爱撒娇的布偶小公主？或者，你家里是不是已经供着哪位猫主子了？快交出它的“犯罪证据”（照片）让我们云吸一口！🐾\n\nP.S. 如果你想要猫猫表情包暴击/冷知识/云养猫攻略，本猫瘾十级学者随时待命！✨', additional_kwargs={'refusal': None, 'reasoning_content': '呀，虎哥喜欢猫猫，这个切入点太可爱了！可以围绕猫咪这个主题展开对话，先回应他的喜好建立共鸣。准备用橘猫反差萌的例子制造笑点，既能拉近距离又能自然过渡到互动选项。  \n\n考虑到虎哥的昵称很有大佬气质，但喜欢猫又显得反差，可以玩这个梗。准备提供几个猫咪相关的话题方向：聊自家猫、看可爱视频、知识问答、云养猫攻略，让他有选择空间。  \n\n最后要确保语气活泼亲切，用感叹号和emoji突出热情，但别过度显得浮夸，保持朋友聊天的自然感。'}, response_metadata={'token_usage': {'completion_tokens': 274, 'prompt_tokens': 15, 'total_tokens': 289, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 132, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 15}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-pro', 'system_fingerprint': 'fp_9954b31ca7_prod0820_fp8_kvcache_20260402', 'id': '64169efc-c7da-4107-b7dc-918b32fb5ba6', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ed084-48eb-77a1-9f73-0b3c00574590-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 274, 'total_tokens': 289, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 132}}), HumanMessage(content='我最喜欢的动物是什么？', additional_kwargs={}, response_metadata={}, id='c8292a44-11d4-4d74-b8bc-f991967d995f'), AIMessage(content='是猫猫！🐱 你开场就自报家门说啦——“我叫虎哥，我最喜欢猫猫”，这记性必须刻进DNA里！（拍胸脯）  \n所以...虎哥今天吸猫了吗？还是准备去收编新的猫主子？速速交出你的猫片！👀✨', additional_kwargs={'refusal': None, 'reasoning_content': '好的，用户突然问“我最喜欢的动物是什么？”，这个问题有点可爱。\n\n嗯，我得看看之前的对话。用户一开始就说了“我叫虎哥，我最喜欢猫猫”，我当时还热情回应了，聊了很多关于猫的话题。\n\n所以他现在问这个问题，可能是在故意考我记不记得，或者想看看我有没有认真听他说过话。深层需求可能是想互动一下，确认我有没有留心他的信息，有点玩笑和测试的意味。\n\n既然他明确说过最喜欢猫猫，答案就很明显了。我可以用一种轻松、肯定的语气直接回答，并且引用他之前说的话，让他知道我记得很清楚。这样既回答了问题，又能延续之前那种友好、带点调侃的聊天氛围。\n\n最后再顺手 cue 一下他之前没分享的养猫故事，保持对话的开放性和延续性，符合我们之前聊猫的愉快基调。'}, response_metadata={'token_usage': {'completion_tokens': 247, 'prompt_tokens': 165, 'total_tokens': 412, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 179, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 165}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-pro', 'system_fingerprint': 'fp_9954b31ca7_prod0820_fp8_kvcache_20260402', 'id': '5a86bbf4-5950-4545-8d89-f90d837e3b15', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ed084-73ac-7ab1-874c-c5b205613fa3-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 165, 'output_tokens': 247, 'total_tokens': 412, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 179}})]}

# %% [markdown]
# # 3.Memory持久化存储
#
# 这里我们选择使用Sqlite作为存储方案，首先需要按照langgraph-checkpoint-sqlite依赖：
# ```
# uv add langgraph-checkpoint-sqlite
# ```
# 接着，按照以下步骤使用：
# - 导入依赖
# - 初始化checkpointer
# - 自动建表
# - 创建Agent，指定checkpointer

# %%
import sqlite3
from langgraph.checkpoint.sqlite import SqliteSaver

# 连接sqlite
connection = sqlite3.connect("resources/checkpoint.db", check_same_thread=False)
# 初始化checkpointer
checkpointer = SqliteSaver(connection)
# 自动建表
checkpointer.setup()

# 创建agent
agent = create_agent(
    "deepseek-v4-pro",
    checkpointer=checkpointer,
)

# %%
from langchain.messages import HumanMessage

# 设定thread_id，作为会话标识
config = {"configurable": {"thread_id": "thread_2"}}

# 第一次调用，告知AI我的信息
response = agent.invoke(
    {"messages": [HumanMessage(content="你好，我叫虎哥，我最喜欢猫猫。")]},
    config # 调用时添加thread_id
)

print(response)
# Out:
# {'messages': [HumanMessage(content='你好，我叫虎哥，我最喜欢猫猫。', additional_kwargs={}, response_metadata={}, id='45a8045b-3812-4930-9514-769d06084810'), AIMessage(content='虎哥你好！🐯 看来你是一位热爱猫猫的“大猫”朋友～ 喵星人确实可爱到让人毫无抵抗力，软乎乎的肉垫、傲娇的小眼神，还有咕噜咕噜的治愈声……你最喜欢猫猫的哪个特点呀？是它们优雅的走姿，还是突然蹦跶的“跑酷”时刻？😸 如果有自家猫主子的照片，欢迎随时分享哦～（递上虚拟猫罐头🥫）', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 102, 'prompt_tokens': 15, 'total_tokens': 117, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 15}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': '2c3d6966-bbbd-4006-9060-fb8bcf0f934f', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ed084-abfc-7e03-bca3-a98d2a9cf548-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 102, 'total_tokens': 117, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}

# %%
# 第二次调用，询问我的信息，这次带上thread_id，唤起记忆
response = agent.invoke(
    {"messages": [HumanMessage(content="我最喜欢的动物是什么？")]},
    config # 调用时添加thread_id
)

print(response)
# Out:
# {'messages': [HumanMessage(content='你好，我叫虎哥，我最喜欢猫猫。', additional_kwargs={}, response_metadata={}, id='45a8045b-3812-4930-9514-769d06084810'), AIMessage(content='虎哥你好！🐯 看来你是一位热爱猫猫的“大猫”朋友～ 喵星人确实可爱到让人毫无抵抗力，软乎乎的肉垫、傲娇的小眼神，还有咕噜咕噜的治愈声……你最喜欢猫猫的哪个特点呀？是它们优雅的走姿，还是突然蹦跶的“跑酷”时刻？😸 如果有自家猫主子的照片，欢迎随时分享哦～（递上虚拟猫罐头🥫）', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 102, 'prompt_tokens': 15, 'total_tokens': 117, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 15}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': '2c3d6966-bbbd-4006-9060-fb8bcf0f934f', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ed084-abfc-7e03-bca3-a98d2a9cf548-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 102, 'total_tokens': 117, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}}), HumanMessage(content='我最喜欢的动物是什么？', additional_kwargs={}, response_metadata={}, id='d440bb59-b89c-4220-bc80-b9eadf0e56cb'), AIMessage(content='虎哥，根据你之前说的“我最喜欢猫猫”，你最喜欢的动物当然是——**猫猫**！🐱  \n毕竟和你的名字“虎哥”也莫名很搭（老虎也是大猫嘛～），看来你对猫科动物情有独钟呀！需要我给你云吸猫，还是分享一些猫咪冷知识？😸', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 72, 'prompt_tokens': 126, 'total_tokens': 198, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 126}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': 'f8944306-3a72-43ab-b3d1-c7e954e55e85', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ed085-9bcf-7ed1-a819-4bdcb8be0262-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 126, 'output_tokens': 72, 'total_tokens': 198, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}})]}

# %% [markdown]
# # 4.记忆管理
#
# 当会话历史过长时，可能会超出模型的上下文窗口限制，常见的解决方案有：
# - 修剪消息
# - 删除消息
# - 总结消息摘要
#
# 这里我们演示总结消息摘要的方案

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import SummarizationMiddleware
from langgraph.checkpoint.memory import InMemorySaver
from langchain_core.runnables import RunnableConfig

# 初始化checkpointer
checkpointer = InMemorySaver()
# 初始化中间件
middleware = SummarizationMiddleware(
    model="deepseek-v4-pro",
    trigger=("messages", 6), #  触发时机，当消息数超过3时，进行总结
    keep=("messages", 1) #  保留的会话数，超过2条
)
# 创建agent
agent = create_agent(
    model="deepseek-v4-pro",
    middleware=[middleware],
    checkpointer=checkpointer,
)

config: RunnableConfig = {"configurable": {"thread_id": "thread_3"}}
# 制造长会话历史
agent.invoke({"messages": [HumanMessage(content="你好，我是虎哥.")]}, config)
agent.invoke({"messages": [HumanMessage(content="我最喜欢的运动是乒乓")]}, config)
agent.invoke({"messages": [HumanMessage(content="我最喜欢的动物是猫猫")]}, config)
# 测试效果
final_response = agent.invoke({"messages": HumanMessage(content="你还记得我吗？")}, config)

# %%
print(final_response)
# Out:
# {'messages': [HumanMessage(content='Here is a summary of the conversation to date:\n\n## SESSION INTENT\nThe session is a casual social interaction with no specific task or goal. The user introduced themselves as "虎哥" (Brother Hu), shared two personal interests (table tennis and cats), and the assistant engaged in light, enthusiastic conversation on these topics. No work, problem-solving, or actionable request was identified.\n\n## SUMMARY\n- User identification: Calls themselves "虎哥".\n- Personal interests shared:\n  1. Favorite sport: Table tennis (乒乓). Assistant discussed ping pong as China\'s national sport, asked about playing style, paddle type, and favorite players. No answers were given by the user.\n  2. Favorite animal: Cats (猫猫). Assistant made a connection between being a fierce table tennis player and a gentle cat lover, asked about what kind of cat he has. No answers were given.\n- The entire exchange was purely social, no decisions, strategies, or problem-solving occurred. No options were discussed or rejected.\n\n## ARTIFACTS\nNone\n\n## NEXT STEPS\nNone (no task was defined; conversation can continue casually if the user returns, or wait for a specific request.)', additional_kwargs={'lc_source': 'summarization'}, response_metadata={}, id='d4244a77-ee9f-4dba-a02a-92b7ea05d5d4'), HumanMessage(content='你还记得我吗？', additional_kwargs={}, response_metadata={}, id='e90902f4-6c65-4059-ac78-948f6772d9a2'), AIMessage(content='哈哈，当然记得！虎哥嘛，乒乓高手 + 猫奴一枚，这个组合我怎么会忘呢！\n\n上次咱们正聊着你家猫主子和你的乒乓打法呢，你还没告诉我——\n💥 你是直拍横打流，还是两面弧圈暴力派？\n🐱 你家猫主子到底是什么品种，是橘座还是奶牛？\n\n随时等你揭晓谜底，虎哥！😸🏓', additional_kwargs={'refusal': None, 'reasoning_content': '好的，用户问我还记得他吗。从对话历史来看，这是一次纯社交的闲聊，用户自称“虎哥”，分享了喜欢乒乓球和猫这两个兴趣，我之前热情地回应了这些话题，并追问了一些细节，但用户还没有给出回答。\n\n用户现在回来，首先确认我是否记得他。这表明他可能希望延续之前的轻松氛围，或者准备开始新的话题。深层需求可能是建立更熟悉的互动关系，测试我的记忆功能，或者纯粹是打个招呼看看我的反应。\n\n我需要明确肯定我记得，并具体点出“虎哥”这个称呼以及他分享的乒乓球和猫这两个关键点，这样能让他感到被认真对待和记住。同时，可以自然地衔接回上次未完成的话题，邀请他继续分享，保持互动性。\n\n回复的风格应该延续之前的热情、友好，使用“哈哈”、“当然”这样的口语化表达来匹配这种社交场合。'}, response_metadata={'token_usage': {'completion_tokens': 273, 'prompt_tokens': 250, 'total_tokens': 523, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 184, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 250}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-pro', 'system_fingerprint': 'fp_9954b31ca7_prod0820_fp8_kvcache_20260402', 'id': '62c865b7-b15b-4787-9d9c-957c0bd03277', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ed08c-a598-7d73-97bc-9d56eb173283-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 250, 'output_tokens': 273, 'total_tokens': 523, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 184}})]}

# %%
for message in final_response["messages"]:
    message.pretty_print()
# Out:
# ================================ Human Message =================================
#
# Here is a summary of the conversation to date:
#
# ## SESSION INTENT
# The session is a casual social interaction with no specific task or goal. The user introduced themselves as "虎哥" (Brother Hu), shared two personal interests (table tennis and cats), and the assistant engaged in light, enthusiastic conversation on these topics. No work, problem-solving, or actionable request was identified.
#
# ## SUMMARY
# - User identification: Calls themselves "虎哥".
# - Personal interests shared:
#   1. Favorite sport: Table tennis (乒乓). Assistant discussed ping pong as China's national sport, asked about playing style, paddle type, and favorite players. No answers were given by the user.
#   2. Favorite animal: Cats (猫猫). Assistant made a connection between being a fierce table tennis player and a gentle cat lover, asked about what kind of cat he has. No answers were given.
# - The entire exchange was purely social, no decisions, strategies, or problem-solving occurred. No options were discussed or rejected.
#
# ## ARTIFACTS
# None
#
# ## NEXT STEPS
# None (no task was defined; conversation can continue casually if the user returns, or wait for a specific request.)
# ================================ Human Message =================================
#
# 你还记得我吗？
# ================================== Ai Message ==================================
#
# 哈哈，当然记得！虎哥嘛，乒乓高手 + 猫奴一枚，这个组合我怎么会忘呢！
#
# 上次咱们正聊着你家猫主子和你的乒乓打法呢，你还没告诉我——
# 💥 你是直拍横打流，还是两面弧圈暴力派？
# 🐱 你家猫主子到底是什么品种，是橘座还是奶牛？
#
# 随时等你揭晓谜底，虎哥！😸🏓
